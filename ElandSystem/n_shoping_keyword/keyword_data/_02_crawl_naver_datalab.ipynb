# %%
import requests
from bs4 import BeautifulSoup as bs
import json
import numpy as np
import datetime
import time
import sys
import os,random
import pandas as pd

def get_data(src_str,basedate,output_file):
    startDate = basedate[:6]
    endDate = datetime.date.today().strftime('%Y%m')
    
    headers = {'Referer': 'https://datalab.naver.com/'
              ,'User-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:69.0) Gecko/20100101 Firefox/69.0'}
    url = 'http://datalab.naver.com/qcHash.naver'
    formdata={'queryGroups': src_str
              , 'startDate': startDate, 'endDate': endDate, 'timeUnit': 'week'
              , 'gender': '', 'age': '','device': ''}
    
    r=requests.post(url,headers=headers,data=formdata)
    hash_data = json.loads(r.text)
    hashKey = hash_data['hashKey']
    #print(hash_data)
    
    trend_url = f'http://datalab.naver.com/keyword/trendResult.naver?hashKey={hashKey}'
    #print(trend_url)
    r=requests.get(trend_url,headers=headers)
    soup = bs(r.text,'lxml')
    graph_raw = soup.find('div',id = 'graph_data').get_text()
    #graph = json.loads(soup.find('div',id = 'graph_data').get_text())
    with open(f'{grp1_path}/{output_file}','a',encoding='utf-8') as f:
        f.write(graph_raw+'\n')
    time.sleep(random.uniform(0.2,0.5))

# %%
## 
#w_date = datetime.datetime.now().strftime("%Y%m%d")
keyword_w_date = '20210201'
output_w_date = '20210215'
grp1_path = './result_data/grp_1st'
output_file=f'keyword_crawling_{output_w_date}.txt'

def naver_crawl2(work_key_cnt,output_file) :
    src_str=''
    cnt=0
    basedate='20170102'
    for i in range(work_key_cnt,work_key_cnt+5):
        #key_grp=rl[i].decode("utf-8").strip().split(',')
        #grp=key_grp[0]
        #key=str.lower(key_grp[1])
        key=rl[i]
        src_str+=key+'__SZLIG__'+key+'__OUML__'
        # 키워드 리스트의 마지막 항목 이거나 그룹핑 최대 횟수에 도달할경우 request처리
        if i==len(rl)-1 or cnt==4:
            #print(src_str)
            #req_cnt += 1
            cnt=-1
            src_str = src_str[:-8]
            #print(src_str)
            get_data(src_str,basedate,output_file)

            #sys.stdout.write(f'\r | {work_key_cnt} / {total_key_cnt} |  /  |     |{src_str}                                                                    ')
            #sys.stdout.flush()
            #src_str=''
        work_key_cnt +=1
        cnt+=1
    return work_key_cnt,total_key_cnt,src_str

df= pd.read_csv(f'./keyword_list/{keyword_w_date}_keyword_list.txt')
rl=df['keyword'].to_list()
grp1_path = './result_data/grp_1st'
total_key_cnt = len(rl)
retry_count = 100
loop_count = 100
work_key_cnt = 78315   
src_str=''
print(datetime.datetime.now())
#9118
#req_cnt = 0

#while loop_count > 0 and retry_count > 0 and work_key_cnt < 453355 :
while work_key_cnt < 150010 :
        try:
             
            #print(work_key_cnt, req_cnt)
            work_key_cnt,total_key_cnt,src_str = naver_crawl2(work_key_cnt,output_file)
            #work_key_cnt = work_key_cnt + (req_cnt *5) +1
            sys.stdout.write(f'\r | {work_key_cnt} / {total_key_cnt} |  /  |     |{src_str}                                                                    ')
            sys.stdout.flush()
            
            loop_count -= 1   

        except Exception:
            #print(work_key_cnt,crawl_cnt)
            #tmp_df=pd.read_csv(f'{grp1_path}/{output_file}',engine='c', error_bad_lines=False)
            #tmp_num = len(tmp_df)
            #work_key_cnt = work_key_cnt + (req_cnt *5) + 1
            print("Failed! Retrying...",work_key_cnt,datetime.datetime.now())
            retry_count -= 1
            loop_count -= 1
            time.sleep(120)
            continue
print(datetime.datetime.now())
# Out:
# 2021-02-15 16:50:07.461820
#  | 80280 / 453355 |  /  |     |symbol__SZLIG__symbol__OUML__쿠론가방신상__SZLIG__쿠론가방신상__OUML__목걸이거치대__SZLIG__목걸이거치대__OUML__춘천애슐리__SZLIG__춘천애슐리__OUML__제니퍼룸오븐__SZLIG__제니퍼룸오븐                                                                                                                  Failed! Retrying... 80280 2021-02-15 16:53:42.220399
# Failed! Retrying... 80280 2021-02-15 16:55:42.265445
# Failed! Retrying... 80280 2021-02-15 16:57:42.307527
# Failed! Retrying... 80280 2021-02-15 16:59:42.356111
# Failed! Retrying... 80280 2021-02-15 17:01:42.409833
#  | 82895 / 453355 |  /  |     |숏패딩__SZLIG__숏패딩__OUML__유니어패럴후드티__SZLIG__유니어패럴후드티__OUML__퍼플렉스시티__SZLIG__퍼플렉스시티__OUML__남성향수__SZLIG__남성향수__OUML__남자겉옷__SZLIG__남자겉옷                                                                                                                Failed! Retrying... 82895 2021-02-15 17:08:29.680055
# Failed! Retrying... 82895 2021-02-15 17:10:29.738093
# Failed! Retrying... 82895 2021-02-15 17:12:29.783388
# Failed! Retrying... 82895 2021-02-15 17:14:29.835597
# Failed! Retrying... 82895 2021-02-15 17:16:29.892155
#  | 86030 / 453355 |  /  |     |얼라이브__SZLIG__얼라이브__OUML__레드콤보__SZLIG__레드콤보__OUML__반스레드__SZLIG__반스레드__OUML__발편한여성구두__SZLIG__발편한여성구두__OUML__한지부채__SZLIG__한지부채                                                                                                                Failed! Retrying... 86030 2021-02-15 17:24:08.053174
# Failed! Retrying... 86030 2021-02-15 17:26:08.105574
# Failed! Retrying... 86030 2021-02-15 17:28:08.170076
# Failed! Retrying... 86030 2021-02-15 17:30:08.216230
# Failed! Retrying... 86030 2021-02-15 17:32:08.274447
#  | 89640 / 453355 |  /  |     |스케이트보드__SZLIG__스케이트보드__OUML__6인용세라믹식탁세트__SZLIG__6인용세라믹식탁세트__OUML__핸드폰자바라거치대__SZLIG__핸드폰자바라거치대__OUML__발렌시아가노벨티__SZLIG__발렌시아가노벨티__OUML__빕스공릉점__SZLIG__빕스공릉점                                                                                          Failed! Retrying... 89640 2021-02-15 17:40:40.717004
# Failed! Retrying... 89640 2021-02-15 17:42:40.769210
# Failed! Retrying... 89640 2021-02-15 17:44:40.822159
# Failed! Retrying... 89640 2021-02-15 17:46:40.873119
# Failed! Retrying... 89640 2021-02-15 17:48:40.919147
#  | 92435 / 453355 |  /  |     |모니터받침대__SZLIG__모니터받침대__OUML__밀라노식당__SZLIG__밀라노식당__OUML__노스페이스봄버__SZLIG__노스페이스봄버__OUML__르몽드__SZLIG__르몽드__OUML__떡가게종춘__SZLIG__떡가게종춘                                                                                                                Failed! Retrying... 92435 2021-02-15 17:55:41.665531
# Failed! Retrying... 92435 2021-02-15 17:57:41.721915
# Failed! Retrying... 92435 2021-02-15 17:59:41.775072
# Failed! Retrying... 92435 2021-02-15 18:01:41.828694
# Failed! Retrying... 92435 2021-02-15 18:03:41.877890
#  | 95205 / 453355 |  /  |     |미키마우스__SZLIG__미키마우스__OUML__에스티유__SZLIG__에스티유__OUML__쌤쏘나이트백팩__SZLIG__쌤쏘나이트백팩__OUML__포켓티__SZLIG__포켓티__OUML__펜디몬트레조미니__SZLIG__펜디몬트레조미니                                                                                                                Failed! Retrying... 95205 2021-02-15 18:10:43.546262
# Failed! Retrying... 95205 2021-02-15 18:12:43.594458
# Failed! Retrying... 95205 2021-02-15 18:14:43.640178
# Failed! Retrying... 95205 2021-02-15 18:16:43.687406
# Failed! Retrying... 95205 2021-02-15 18:18:43.742965
#  | 99000 / 453355 |  /  |     |귓속말__SZLIG__귓속말__OUML__엔트리원더스에어프라이어__SZLIG__엔트리원더스에어프라이어__OUML__이천더이진__SZLIG__이천더이진__OUML__자넬라토스몰__SZLIG__자넬라토스몰__OUML__카시야__SZLIG__카시야                                                                                                        Failed! Retrying... 99000 2021-02-15 18:27:33.878293
# Failed! Retrying... 99000 2021-02-15 18:29:33.925498
# Failed! Retrying... 99000 2021-02-15 18:31:33.971514
# Failed! Retrying... 99000 2021-02-15 18:33:34.020238
# Failed! Retrying... 99000 2021-02-15 18:35:34.066230
#  | 103130 / 453355 |  /  |     |hp__SZLIG__hp__OUML__다오배찌붐힐대소동__SZLIG__다오배찌붐힐대소동__OUML__문화제__SZLIG__문화제__OUML__유인나마스크__SZLIG__유인나마스크__OUML__몽슈레베개__SZLIG__몽슈레베개                                                                                                              Failed! Retrying... 103130 2021-02-15 18:45:03.377898
# Failed! Retrying... 103130 2021-02-15 18:47:03.431233
# Failed! Retrying... 103130 2021-02-15 18:49:03.475720
# Failed! Retrying... 103130 2021-02-15 18:51:03.524683
# Failed! Retrying... 103130 2021-02-15 18:53:03.572931
#  | 106345 / 453355 |  /  |     |견미리팩트시즌6__SZLIG__견미리팩트시즌6__OUML__리모와전자태그__SZLIG__리모와전자태그__OUML__가죽클러치__SZLIG__가죽클러치__OUML__이천렌트카__SZLIG__이천렌트카__OUML__양가죽부츠__SZLIG__양가죽부츠                                                                                                          Failed! Retrying... 106345 2021-02-15 19:00:50.036720
# Failed! Retrying... 106345 2021-02-15 19:02:50.084100
# Failed! Retrying... 106345 2021-02-15 19:04:50.133172
# Failed! Retrying... 106345 2021-02-15 19:06:50.191315
# Failed! Retrying... 106345 2021-02-15 19:08:50.236909
#  | 109710 / 453355 |  /  |     |초등교과서__SZLIG__초등교과서__OUML__서귀포올레시장주차장__SZLIG__서귀포올레시장주차장__OUML__오아시스청담__SZLIG__오아시스청담__OUML__아시테지겨울축제__SZLIG__아시테지겨울축제__OUML__바쏘패딩__SZLIG__바쏘패딩                                                                                                              Failed! Retrying... 109710 2021-02-15 19:16:57.795523
# Failed! Retrying... 109710 2021-02-15 19:18:57.846540
# Failed! Retrying... 109710 2021-02-15 19:20:57.893180
# Failed! Retrying... 109710 2021-02-15 19:22:57.944341
# Failed! Retrying... 109710 2021-02-15 19:24:57.997033
#  | 114185 / 453355 |  /  |     |남자보드복__SZLIG__남자보드복__OUML__맥도날드채용__SZLIG__맥도날드채용__OUML__이마트노브랜드마카롱__SZLIG__이마트노브랜드마카롱__OUML__troisrois__SZLIG__troisrois__OUML__싱가포르게스트하우스__SZLIG__싱가포르게스트하우스                                                                                                    Failed! Retrying... 114185 2021-02-15 19:34:59.383633
# Failed! Retrying... 114185 2021-02-15 19:36:59.431118
# Failed! Retrying... 114185 2021-02-15 19:38:59.480488
# Failed! Retrying... 114185 2021-02-15 19:40:59.531582
# Failed! Retrying... 114185 2021-02-15 19:42:59.579856
#  | 118305 / 453355 |  /  |     |온천가족탕__SZLIG__온천가족탕__OUML__보니스팍스점퍼__SZLIG__보니스팍스점퍼__OUML__안동키햐아__SZLIG__안동키햐아__OUML__애슐리무제한스테이크__SZLIG__애슐리무제한스테이크__OUML__카이아크만청바지__SZLIG__카이아크만청바지                                                                                              Failed! Retrying... 118305 2021-02-15 19:52:25.109138
# Failed! Retrying... 118305 2021-02-15 19:54:25.164481
# Failed! Retrying... 118305 2021-02-15 19:56:25.217822
# Failed! Retrying... 118305 2021-02-15 19:58:25.266903
# Failed! Retrying... 118305 2021-02-15 20:00:25.313027
#  | 121460 / 453355 |  /  |     |eosm3__SZLIG__eosm3__OUML__울진군의료원__SZLIG__울진군의료원__OUML__아식스신발__SZLIG__아식스신발__OUML__시바견바디쿠션__SZLIG__시바견바디쿠션__OUML__충남당진펜션__SZLIG__충남당진펜션                                                                                                                      Failed! Retrying... 121460 2021-02-15 20:08:07.566822
# Failed! Retrying... 121460 2021-02-15 20:10:07.619822
# Failed! Retrying... 121460 2021-02-15 20:12:07.669231
# Failed! Retrying... 121460 2021-02-15 20:14:07.727878
# Failed! Retrying... 121460 2021-02-15 20:16:07.778800
#  | 125305 / 453355 |  /  |     |경주대명리조트아쿠아월드__SZLIG__경주대명리조트아쿠아월드__OUML__몬테크리스토만들기__SZLIG__몬테크리스토만들기__OUML__세미배기팬츠__SZLIG__세미배기팬츠__OUML__맥심아라비카__SZLIG__맥심아라비카__OUML__낙산항팔도횟집__SZLIG__낙산항팔도횟집                                                                                            Failed! Retrying... 125305 2021-02-15 20:25:05.456028
# Failed! Retrying... 125305 2021-02-15 20:27:05.522147
# Failed! Retrying... 125305 2021-02-15 20:29:05.565756
# Failed! Retrying... 125305 2021-02-15 20:31:05.614986
# Failed! Retrying... 125305 2021-02-15 20:33:05.664795
#  | 129335 / 453355 |  /  |     |버빌리안3d백팩__SZLIG__버빌리안3d백팩__OUML__샤넬수분크림__SZLIG__샤넬수분크림__OUML__부산얼짱쭈꾸미__SZLIG__부산얼짱쭈꾸미__OUML__용인토지매매__SZLIG__용인토지매매__OUML__오니츠카타이거멕시코66흰검__SZLIG__오니츠카타이거멕시코66흰검                                                                                                                            Failed! Retrying... 129335 2021-02-15 20:42:24.741084
# Failed! Retrying... 129335 2021-02-15 20:44:24.794413
# Failed! Retrying... 129335 2021-02-15 20:46:24.843059
# Failed! Retrying... 129335 2021-02-15 20:48:24.895490
# Failed! Retrying... 129335 2021-02-15 20:50:24.948624
#  | 133045 / 453355 |  /  |     |너의이름은만화__SZLIG__너의이름은만화__OUML__성수동글로우__SZLIG__성수동글로우__OUML__랩딜리버리__SZLIG__랩딜리버리__OUML__이천노브랜드__SZLIG__이천노브랜드__OUML__제옥스모에나__SZLIG__제옥스모에나                                                                                                                    Failed! Retrying... 133045 2021-02-15 20:59:09.767494
# Failed! Retrying... 133045 2021-02-15 21:01:09.812599
# Failed! Retrying... 133045 2021-02-15 21:03:09.862138
# Failed! Retrying... 133045 2021-02-15 21:05:09.918690
# Failed! Retrying... 133045 2021-02-15 21:07:09.976957
#  | 136160 / 453355 |  /  |     |꿈비범퍼침대__SZLIG__꿈비범퍼침대__OUML__민소매남방__SZLIG__민소매남방__OUML__깐풍새우만드는법__SZLIG__깐풍새우만드는법__OUML__스톤아일랜드블루종__SZLIG__스톤아일랜드블루종__OUML__일리라떼__SZLIG__일리라떼                                                                                                      Failed! Retrying... 136160 2021-02-15 21:14:45.757286
# Failed! Retrying... 136160 2021-02-15 21:16:45.806088
# Failed! Retrying... 136160 2021-02-15 21:18:45.853014
# Failed! Retrying... 136160 2021-02-15 21:20:45.904323
# Failed! Retrying... 136160 2021-02-15 21:22:45.954918
#  | 140280 / 453355 |  /  |     |아미보__SZLIG__아미보__OUML__경기도광주퇴촌__SZLIG__경기도광주퇴촌__OUML__이마트트레이더스인천__SZLIG__이마트트레이더스인천__OUML__자라데님자켓__SZLIG__자라데님자켓__OUML__톰브라운여성__SZLIG__톰브라운여성                                                                                                                  Failed! Retrying... 140280 2021-02-15 21:32:10.326525
# Failed! Retrying... 140280 2021-02-15 21:34:10.387101
# Failed! Retrying... 140280 2021-02-15 21:36:10.439505
# Failed! Retrying... 140280 2021-02-15 21:38:10.494797
# Failed! Retrying... 140280 2021-02-15 21:40:10.543460
#  | 144545 / 453355 |  /  |     |델라스텔라가방__SZLIG__델라스텔라가방__OUML__소사태__SZLIG__소사태__OUML__어묵볶음밥__SZLIG__어묵볶음밥__OUML__스틸시리즈라이벌310__SZLIG__스틸시리즈라이벌310__OUML__바비브로스__SZLIG__바비브로스                                                                                                          Failed! Retrying... 144545 2021-02-15 21:49:51.333873
# Failed! Retrying... 144545 2021-02-15 21:51:51.392005
# Failed! Retrying... 144545 2021-02-15 21:53:51.441841
# Failed! Retrying... 144545 2021-02-15 21:55:51.496785
# Failed! Retrying... 144545 2021-02-15 21:57:51.545684
#  | 147745 / 453355 |  /  |     |핫앤핫핫팩__SZLIG__핫앤핫핫팩__OUML__여자거즈남방__SZLIG__여자거즈남방__OUML__영주코아루노블__SZLIG__영주코아루노블__OUML__raskal__SZLIG__raskal__OUML__올젠패딩조끼__SZLIG__올젠패딩조끼                                                                                                        Failed! Retrying... 147745 2021-02-15 22:05:31.645419
# Failed! Retrying... 147745 2021-02-15 22:07:31.715412
# Failed! Retrying... 147745 2021-02-15 22:09:31.761889
# Failed! Retrying... 147745 2021-02-15 22:11:31.813410
# Failed! Retrying... 147745 2021-02-15 22:13:31.871331
#  | 150010 / 453355 |  /  |     |실타프__SZLIG__실타프__OUML__노스페이스남성샌들__SZLIG__노스페이스남성샌들__OUML__영덕맛집해상회식당__SZLIG__영덕맛집해상회식당__OUML__삼성전자j3portableusb3.0__SZLIG__삼성전자j3portableusb3.0__OUML__왕뽕__SZLIG__왕뽕                                                                              2021-02-15 22:19:35.320830
