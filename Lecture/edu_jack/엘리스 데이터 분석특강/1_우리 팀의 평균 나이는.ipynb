# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # [NIPA 입문과정] 우리 팀의 평균 나이는?

# %% [markdown]
# ## 네이버 오픈 API - https://developers.naver.com/docs/common/openapiguide/

# %% [markdown]
# ### 이미지캡차 예시 코드 - https://developers.naver.com/docs/utils/captcha/examples/#python

# %%
import os
import sys
import requests

# 등록된 client_id, client_secret 정보를 입력합니다.
client_id = "MPDVrMg7LijEyXthHcTq"
client_secret = "bj1XcVAzcO"

# 얼굴 사진을 통한 나이 추정을 위해서는 아래 url을 사용합니다. (face: 얼굴 분석, celebrity: 닮은 유명인 찾기)
url = "https://openapi.naver.com/v1/vision/face" 
#url = "https://openapi.naver.com/v1/vision/celebrity" 

# 분석할 이미지의 파일명을 입력합니다.
files = {'image': open('style_5ecbc5f096041.jpg', 'rb')}

# API 입력 설정
headers = {'X-Naver-Client-Id': client_id, 'X-Naver-Client-Secret': client_secret }

# API 사용
response = requests.post(url,  files=files, headers=headers)
rescode = response.status_code

if(rescode==200):
    # 결과물 출력
    print (response.text)
else:
    print("Error Code:" + rescode)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-cf104ca248f8> in <module>()
#      12
#      13 # 분석할 이미지의 파일명을 입력합니다.
# ---> 14 files = {'image': open('style_5ecbc5f096041.jpg', 'rb')}
#      15
#      16 # API 입력 설정
#
# FileNotFoundError: [Errno 2] No such file or directory: 'style_5ecbc5f096041.jpg'

# %%
# json 형식을 사용하기 위하여 import 합니다.
import json

# loads 함수를 사용하여 json으로 변환합니다.
result = json.loads(response.text)
result
# Out:
# {'info': {'size': {'width': 1088, 'height': 808}, 'faceCount': 1},
#  'faces': [{'roi': {'x': 401, 'y': 228, 'width': 284, 'height': 284},
#    'landmark': {'leftEye': {'x': 464, 'y': 291},
#     'rightEye': {'x': 603, 'y': 298},
#     'nose': {'x': 535, 'y': 365},
#     'leftMouth': {'x': 461, 'y': 433},
#     'rightMouth': {'x': 598, 'y': 440}},
#    'gender': {'value': 'male', 'confidence': 0.992182},
#    'age': {'value': '19~23', 'confidence': 1.0},
#    'emotion': {'value': 'smile', 'confidence': 0.999924},
#    'pose': {'value': 'frontal_face', 'confidence': 0.998407}}]}

# %%
# 나이에 대한 데이터를 출력합니다.
result['faces'][0]['age']['value']
# Out:
# '19~23'

# %%
# 최소 나이를 int형으로 출력합니다.
int(result['faces'][0]['age']['value'].split('~')[0])
# Out:
# 19

# %%
# 최대 나이를 int형으로 출력합니다.
int(result['faces'][0]['age']['value'].split('~')[1])
# Out:
# 23
